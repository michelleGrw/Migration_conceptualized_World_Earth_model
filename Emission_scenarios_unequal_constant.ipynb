# %%
using ModelingToolkit, OrdinaryDiffEq, CairoMakie, Plots

# %%
@parameters t r₁ Kp₁ r₂ Kp₂ m21 #human population dynamics
@parameters δ₁ δ₂ σ₁ σ₂ s₁ s₂ Cₘ₁ Cₘ₂ a₁ a₂ #economic dynamics
@parameters re₁ re₂ eb u α α₁ α₂ G₀ G₁ Tg η #earth system and climate 


#state variables

@variables P₁(t) P₂(t) K₁(t) K₂(t) G(t) e₁(t) e₂(t) z(t)


θ(x) = (max(0,x))^5/(0.0001^5 + (max(0,x))^5)
@register θ(x)


ϕ(x) = x*θ(x)
@register ϕ(x)


Yᵢ(a,α,K,P) = a*((ϕ(K))^α)*(P^(1-α))
@register Yᵢ(a,α,K,P)

Yᵢ₁ = Yᵢ(a₁,α₁,K₁,P₁)
Yᵢ₂ = Yᵢ(a₂,α₂,K₂,P₂)

Y(P,Y) = P + ϕ(Y-P)
@register Y(P,K)

Y₁ = Y(P₁,Yᵢ₁)
Y₂ = Y(P₂,Yᵢ₂)

er₁ = θ(P₁-Yᵢ₁)*eb + θ(Yᵢ₁-P₁)*e₁
er₂ = θ(P₂-Yᵢ₂)*eb + θ(Yᵢ₂-P₂)*e₂

Yd₁ = ϕ(Y₁ - P₁*Cₘ₁)
Yd₂ = ϕ(Y₂ - P₂*Cₘ₂)

D = Differential(t)

eqs = [
    D(P₁) ~ r₁*P₁*(1 - P₁/Kp₁)+m21*P₂, #human population dynamics 
    D(P₂) ~ r₂*P₂*(1 - P₂/Kp₂)-m21*P₂, # standard logistic.
    D(K₁) ~ s₁*Yd₁ - δ₁*K₁ - σ₁*exp(G-G₁)*K₁, #change in capital stock = 
    D(K₂) ~ s₂*Yd₂ - δ₂*K₂ - σ₂*exp(G-G₁)*K₂, # savings-depreciation-damages
    D(G)  ~ er₁*Y₁ + er₂*Y₂ - u*(G-2.8) + α*θ(G-G₀), # global externality.
    D(z)  ~ η*θ(G-Tg)*(1-z), #initiate decarbonization - Tg
    D(e₁) ~ -z*re₁*e₁, # decarbonization in region 1
    D(e₂) ~ -z*re₂*e₂ # decarbonization in region 2
    ]

@named sys = ODESystem(eqs);

# %%
e_vary = [0.0001,0.0004,0.005]

l = length(e_vary)
years = LinRange(1900,2501,601)
G_vary = zeros(l,601);
P1_vary = zeros(l,601);
P2_vary = zeros(l,601);
K1_vary = zeros(l,601);
K2_vary = zeros(l,601);
O1_vary = zeros(l,601);
O2_vary = zeros(l,601);
OT_vary = zeros(l,601);
PCO1_vary = zeros(l,601);
PCO2_vary = zeros(l,601);

G_vary_m1 = zeros(l,601);
P1_vary_m1 = zeros(l,601);
P2_vary_m1 = zeros(l,601);
K1_vary_m1 = zeros(l,601);
K2_vary_m1 = zeros(l,601);
O1_vary_m1 = zeros(l,601);
O2_vary_m1 = zeros(l,601);
OT_vary_m1 = zeros(l,601);
PCO1_vary_m1 = zeros(l,601);
PCO2_vary_m1 = zeros(l,601);
P_vary = zeros(l,601);
P_vary_m1= zeros(l,601);
P_vary_m2 = zeros(l,601);

G_vary_m2 = zeros(l,601);
P1_vary_m2 = zeros(l,601);
P2_vary_m2 = zeros(l,601);
K1_vary_m2 = zeros(l,601);
K2_vary_m2 = zeros(l,601);
O1_vary_m2 = zeros(l,601);
O2_vary_m2 = zeros(l,601);
OT_vary_m2 = zeros(l,601);
PCO1_vary_m2 = zeros(l,601);
PCO2_vary_m2 = zeros(l,601);

# %%
## ZERO MIGRATION _ SOLID LINE 
for i in 1:3

# assign values to parameters
p=[r₁=>0.038, Kp₁=>1.5, #populatin growth, carrying capacity
    r₂=>0.042, Kp₂=>9.7, #populatin growth, carrying capacity
    α₁=>0.5, α₂=>0.5, #capital factor productivity
    a₁=>2.7, a₂=>1.7, #total factor productivity
    δ₁=>0.05, δ₂=>0.05, #capital entropic decay rates  
    s₁=>0.25, s₂=>0.21, #savings rates (of disposable income)
    Cₘ₁=>0.7, Cₘ₂=>0.7, #minimum subsistence consumption
    σ₁=>0.03, σ₂=>0.03, #climate damages on infrastructure
    re₁=>0.01, re₂=>0.01, eb=>0.00004, Tg=>20, #carbon intensities
    η=>1, #rate at which decarbonization is initiated
    u=>0.0025, α=>0.1, #earth system carbon uptake and release
    G₁=>5, G₀=>20,#g0_vary[i] #G1=damage threshold, G₀ = climate threshold 
    m21=> 0
]

#set initial conditions

u0=[P₁=>0.24,P₂=>0.24,K₁=>0,K₂=>0,
    G=>2.8,e₁=>e_vary[i],e₂=>e_vary[i],z=>0]

#set time span for integrating the system

tspan=(0.0,600.0); #time span in years.

prob=ODEProblem(sys,u0,tspan,p);

sol=solve(prob,Tsit5(),saveat=1.0);  


P1_vary[i,:] = sol[1,:];
P2_vary[i,:] = sol[2,:];
K1_vary[i,:]= sol[3,:];
K2_vary[i,:] = sol[4,:];
G_vary[i,:] = sol[5,:];
#em₁ = sol[7,:];
#em₂ = sol[8,:];
t = sol.t;

#G_vary[i,:] = g

O(a,α,K,P) = max.(P, a*(K.^α).*(P.^(1-α)));

O1_vary[i,:] = O(p[7][2],p[5][2],K1_vary[i,:],P1_vary[i,:]);
O2_vary[i,:] = O(p[8][2],p[6][2],K2_vary[i,:],P2_vary[i,:]);

OT_vary[i,:] = O1_vary[i,:] + O2_vary[i,:];

# using PCO for per capita output....

PCO1_vary[i,:] = O1_vary[i,:]./P1_vary[i,:];   
PCO2_vary[i,:] = O2_vary[i,:]./P2_vary[i,:];
P_vary[i,:] = P1_vary[i,:]+P2_vary[i,:]
end

# %%
## Small migration rate_ DOT LINE m21 = 0.001
for i in 1:3

    # assign values to parameters
    p=[r₁=>0.038, Kp₁=>1.5, #populatin growth, carrying capacity
        r₂=>0.042, Kp₂=>9.7, #populatin growth, carrying capacity
        α₁=>0.5, α₂=>0.5, #capital factor productivity
        a₁=>2.7, a₂=>1.7, #total factor productivity
        δ₁=>0.05, δ₂=>0.05, #capital entropic decay rates  
        s₁=>0.25, s₂=>0.21, #savings rates (of disposable income)
        Cₘ₁=>0.7, Cₘ₂=>0.7, #minimum subsistence consumption
        σ₁=>0.03, σ₂=>0.03, #climate damages on infrastructure
        re₁=>0.01, re₂=>0.01, eb=>0.00004, Tg=>20, #carbon intensities
        η=>1, #rate at which decarbonization is initiated
        u=>0.0025, α=>0.1, #earth system carbon uptake and release
        G₁=>5, G₀=>20,#g0_vary[i] #G1=damage threshold, G₀ = climate threshold 
        m21 => 0.001
    ]
    
    #set initial conditions
    
    u0=[P₁=>0.24,P₂=>0.24,K₁=>0,K₂=>0,
        G=>2.8,e₁=>e_vary[i],e₂=>e_vary[i],z=>0]
    
    #set time span for integrating the system
    
    tspan=(0.0,600.0); #time span in years.
    
    prob=ODEProblem(sys,u0,tspan,p);
    
    sol=solve(prob,Tsit5(),saveat=1.0);  
    
    
    P1_vary_m1[i,:] = sol[1,:];
    P2_vary_m1[i,:] = sol[2,:];
    K1_vary_m1[i,:]= sol[3,:];
    K2_vary_m1[i,:] = sol[4,:];
    G_vary_m1[i,:] = sol[5,:];
    #em₁ = sol[7,:];
    #em₂ = sol[8,:];
    t = sol.t;
    
    #G_vary[i,:] = g
    
    O(a,α,K,P) = max.(P, a*(K.^α).*(P.^(1-α)));
    
    O1_vary_m1[i,:] = O(p[7][2],p[5][2],K1_vary_m1[i,:],P1_vary_m1[i,:]);
    O2_vary_m1[i,:] = O(p[8][2],p[6][2],K2_vary_m1[i,:],P2_vary_m1[i,:]);
    
    OT_vary_m1[i,:] = O1_vary_m1[i,:] + O2_vary_m1[i,:];
    
    # using PCO for per capita output....
    
    PCO1_vary_m1[i,:] = O1_vary_m1[i,:]./P1_vary_m1[i,:];   
    PCO2_vary_m1[i,:] = O2_vary_m1[i,:]./P2_vary_m1[i,:];
    P_vary_m1[i,:] = P1_vary_m1[i,:]+P2_vary_m1[i,:]

    end

# %%
## big migration rate_ dot dash LINE 0.01
for i in 1:3

    # assign values to parameters
    p=[r₁=>0.038, Kp₁=>1.5, #populatin growth, carrying capacity
        r₂=>0.042, Kp₂=>9.7, #populatin growth, carrying capacity
        α₁=>0.5, α₂=>0.5, #capital factor productivity
        a₁=>2.7, a₂=>1.7, #total factor productivity
        δ₁=>0.05, δ₂=>0.05, #capital entropic decay rates  
        s₁=>0.25, s₂=>0.21, #savings rates (of disposable income)
        Cₘ₁=>0.7, Cₘ₂=>0.7, #minimum subsistence consumption
        σ₁=>0.03, σ₂=>0.03, #climate damages on infrastructure
        re₁=>0.01, re₂=>0.01, eb=>0.00004, Tg=>20, #carbon intensities
        η=>1, #rate at which decarbonization is initiated
        u=>0.0025, α=>0.1, #earth system carbon uptake and release
        G₁=>5, G₀=>20,#g0_vary[i] #G1=damage threshold, G₀ = climate threshold 
        m21 => 0.01
    ]
    
    #set initial conditions
    
    u0=[P₁=>0.24,P₂=>0.24,K₁=>0,K₂=>0,
        G=>2.8,e₁=>e_vary[i],e₂=>e_vary[i],z=>0]
    
    #set time span for integrating the system
    
    tspan=(0.0,600.0); #time span in years.
    
    prob=ODEProblem(sys,u0,tspan,p);
    
    sol=solve(prob,Tsit5(),saveat=1.0);  
    
    
    P1_vary_m2[i,:] = sol[1,:];
    P2_vary_m2[i,:] = sol[2,:];
    K1_vary_m2[i,:]= sol[3,:];
    K2_vary_m2[i,:] = sol[4,:];
    G_vary_m2[i,:] = sol[5,:];
    #em₁ = sol[7,:];
    #em₂ = sol[8,:];
    t = sol.t;
    
    #G_vary[i,:] = g
    
    O(a,α,K,P) = max.(P, a*(K.^α).*(P.^(1-α)));
    
    O1_vary_m2[i,:] = O(p[7][2],p[5][2],K1_vary_m2[i,:],P1_vary_m2[i,:]);
    O2_vary_m2[i,:] = O(p[8][2],p[6][2],K2_vary_m2[i,:],P2_vary_m2[i,:]);
    
    OT_vary_m2[i,:] = O1_vary_m2[i,:] + O2_vary_m2[i,:];
    
    # using PCO for per capita output....
    
    PCO1_vary_m2[i,:] = O1_vary_m2[i,:]./P1_vary_m2[i,:];   
    PCO2_vary_m2[i,:] = O2_vary_m2[i,:]./P2_vary_m2[i,:];
    P_vary_m2[i,:] = P1_vary_m2[i,:]+P2_vary_m2[i,:]
    end

# %%
f2=Figure(backgroundcolor = :white, resolution = (950, 700))

a=Axis(f2[2,1], ylabel = "(ii) \n \n \n Billion People ",xticks=0:200:length(t))
b=Axis(f2[3 ,1], ylabel = "(iii) \n \n GNI \n (\$/10¹²)",xticks=0:200:length(t),limits=(-25,625,-5,95),yticks=0:20:80)
bb = Axis(f2[1,1], ylabel = "(i) \n \n Atm CO2 \n (ppm)" ,title = "(a) \n \n Low Emissions",xticks=0:200:length(t),limits=(-25,625,-5,830),yticks=0:200:800)
c=Axis(f2[4,1], ylabel = "(iv) \n \n Per capita GNI \n (\$/10³)",xticks=0:200:length(t),limits=(-25,625,-1,35),yticks=0:10:30)
d=Axis(f2[2,2],xticks=0:200:length(t))
e=Axis(f2[3,2],xticks=0:200:length(t),limits=(-25,625,-5,95),yticks=0:20:80)
ee = Axis(f2[1,2], title = "(b) \n \n Moderate Emissions",xticks=0:200:length(t),limits=(-25,625,-5,830),yticks=0:200:800)
f=Axis(f2[4,2],xlabel = "Time (Years)",xticks=0:200:length(t),limits=(-25,625,-1,35),yticks=0:10:30)
gg=Axis(f2[2,3], xticks=0:200:length(t))
h=Axis(f2[3,3],xticks=0:200:length(t),limits=(-25,625,-5,95),yticks=0:20:80)
hi = Axis(f2[1,3],title = "(c) \n \n High Emissions",xticks=0:200:length(t),limits=(-25,625,-5,830),yticks=0:200:800)
ii=Axis(f2[4,3], xticks=0:200:length(t),limits=(-25,625,-1,35),yticks=0:10:30)

#define the plots (the variables to plot) to show
###population: a,d,gg
h9=lines!(a,t,P1_vary[1,:],color = :dodgerblue2)
h10=lines!(a,t,P2_vary[1,:],color = :orangered)
h11=lines!(a,t,P1_vary[1,:]+P2_vary[1,:],color = :gray)
lines!(d,t,P1_vary[2,:],color = :dodgerblue2)
lines!(d,t,P2_vary[2,:],color = :orangered)
lines!(d,t,P1_vary[2,:]+P2_vary[2,:],color = :gray)
lines!(gg,t,P1_vary[3,:],color = :dodgerblue2)
lines!(gg,t,P2_vary[3,:],color = :orangered)
lines!(gg,t,P_vary[3,:],color = :gray)

lines!(a,t,P1_vary_m1[1,:],linestyle=:dash,color = :dodgerblue2)
lines!(a,t,P2_vary_m1[1,:],linestyle=:dash,color = :orangered)
lines!(a,t,P_vary_m1[1,:], linestyle=:dash,color = :gray)
lines!(d,t,P1_vary_m1[2,:],linestyle=:dash,color = :dodgerblue2)
lines!(d,t,P2_vary_m1[2,:],linestyle=:dash,color = :orangered)
lines!(d,t,P_vary_m1[2,:], linestyle=:dash,color = :gray)
lines!(gg,t,P1_vary_m1[3,:],linestyle=:dash,color = :dodgerblue2)
lines!(gg,t,P2_vary_m1[3,:],linestyle=:dash,color = :orangered)
lines!(gg,t,P_vary_m1[3,:], linestyle=:dash,color = :gray)

lines!(a,t,P1_vary_m2[1,:],color = :dodgerblue2,linestyle=:dot)
lines!(a,t,P2_vary_m2[1,:],linestyle=:dot,color = :orangered)
lines!(a,t,P_vary_m2[1,:], linestyle=:dot,color = :gray)
lines!(d,t,P1_vary_m2[2,:],color = :dodgerblue2,linestyle=:dot)
lines!(d,t,P2_vary_m2[2,:],linestyle=:dot,color = :orangered)
lines!(d,t,P_vary_m2[2,:], linestyle=:dot,color = :gray)
lines!(gg,t,P1_vary_m2[3,:],color = :dodgerblue2,linestyle=:dot)
lines!(gg,t,P2_vary_m2[3,:],linestyle=:dot,color = :orangered)
lines!(gg,t,P_vary_m2[3,:], linestyle=:dot,color = :gray)


### capital: b,e,h
h4=lines!(b,t,O1_vary[1,:],color = :dodgerblue2)
h5=lines!(b,t,O2_vary[1,:],color = :orangered)
h6=lines!(bb,t,G_vary[1,:]*100,color = :green)
lines!(e,t,O1_vary[2,:],color = :dodgerblue2)
lines!(e,t,O2_vary[2,:],color = :orangered)
lines!(ee,t,100*G_vary[2,:],color = :green)
lines!(h,t,O1_vary[3,:],color = :dodgerblue2)
lines!(h,t,O2_vary[3,:],color = :orangered)
lines!(hi,t,100*G_vary[3,:],color = :lightgreen)

lines!(b,t,O1_vary_m1[1,:],linestyle=:dash,color = :dodgerblue2)
lines!(b,t,O2_vary_m1[1,:],linestyle=:dash,color = :orangered)
lines!(bb,t,G_vary_m1[1,:]*100,color = :green,linestyle=:dash)
lines!(e,t,O1_vary_m1[2,:],linestyle=:dash,color = :dodgerblue2)
lines!(e,t,O2_vary_m1[2,:],linestyle=:dash,color = :orangered)
lines!(ee,t,100*G_vary_m1[2,:],color = :green,linestyle=:dash)
lines!(h,t,O1_vary_m1[3,:],linestyle=:dash,color = :dodgerblue2)
lines!(h,t,O2_vary_m1[3,:],linestyle=:dash,color = :orangered)
lines!(hi,t,100*G_vary_m1[3,:],color = :green)

lines!(b,t,O1_vary_m2[1,:],linestyle=:dot,color = :dodgerblue2)
lines!(b,t,O2_vary_m2[1,:],linestyle=:dot,color = :orangered)
lines!(bb,t,G_vary_m2[1,:]*100,linestyle=:dot,color = :green)
lines!(e,t,O1_vary_m2[2,:],linestyle=:dot,color = :dodgerblue2)
lines!(e,t,O2_vary_m2[2,:],linestyle=:dot,color = :orangered)
lines!(ee,t,100*G_vary_m2[2,:],linestyle=:dot,color = :green)
lines!(h,t,O1_vary_m2[3,:],linestyle=:dot,color = :dodgerblue2)
lines!(h,t,O2_vary_m2[3,:],linestyle=:dot,color = :orangered)
lines!(hi,t,100*G_vary_m2[3,:],linestyle=:dot,color = :green)

###per capita capital c,f,ii
h7=lines!(c,t,O1_vary[1,:]./P1_vary[1,:],color = :dodgerblue2)
h8=lines!(c,t,O2_vary[1,:]./P2_vary[1,:],color = :orangered)
lines!(f,t,O1_vary[2,:]./P1_vary[2,:],color = :dodgerblue2)
lines!(f,t,O2_vary[2,:]./P2_vary[2,:],color = :orangered)
lines!(ii,t,O1_vary[3,:]./P1_vary[3,:],color = :dodgerblue2)
lines!(ii,t,O2_vary[3,:]./P2_vary[3,:],color = :orangered)

lines!(c,t,O1_vary_m1[1,:]./P1_vary_m1[1,:],linestyle=:dash,color = :dodgerblue2)
lines!(c,t,O2_vary_m1[1,:]./P2_vary_m1[1,:],linestyle=:dash,color = :orangered)
lines!(f,t,O1_vary_m1[2,:]./P1_vary_m1[2,:],linestyle=:dash,color = :dodgerblue2)
lines!(f,t,O2_vary_m1[2,:]./P2_vary_m1[2,:],linestyle=:dash,color = :orangered)
lines!(ii,t,O1_vary_m1[3,:]./P1_vary_m1[3,:],linestyle=:dash,color = :dodgerblue2)
lines!(ii,t,O2_vary_m1[3,:]./P2_vary_m1[3,:],linestyle=:dash,color = :orangered)

lines!(c,t,O1_vary_m2[1,:]./P1_vary_m2[1,:],linestyle=:dot,color = :dodgerblue2)
lines!(c,t,O2_vary_m2[1,:]./P2_vary_m2[1,:],linestyle=:dot,color = :orangered)
lines!(f,t,O1_vary_m2[2,:]./P1_vary_m2[2,:],linestyle=:dot,color = :dodgerblue2)
lines!(f,t,O2_vary_m2[2,:]./P2_vary_m2[2,:],linestyle=:dot,color = :orangered)
lines!(ii,t,O1_vary_m2[3,:]./P1_vary_m2[3,:],linestyle=:dot,color = :dodgerblue2)
lines!(ii,t,O2_vary_m2[3,:]./P2_vary_m2[3,:],linestyle=:dot,color = :orangered)


#set the legend
Legend(f2[5,1:3],[h4,h5,h6],["High Income Region","Low Income Region","Global Externality"])

f2
# Out:
# ┌ Warning: Found `resolution` in the theme when creating a `Scene`. The `resolution` keyword for `Scene`s and `Figure`s has been deprecated. Use `Figure(; size = ...` or `Scene(; size = ...)` instead, which better reflects that this is a unitless size and not a pixel resolution. The key could also come from `set_theme!` calls or related theming functions.
# └ @ Makie C:\Users\admin\.julia\packages\Makie\rEu75\src\scenes.jl:227

# %%
save("emission_constanrate_dash_0p001_dot_0p01.svg",f2)
# Out:
# CairoMakie.Screen{SVG}

# %%
f4 = Figure(resolution = (950, 900))
a=Axis(f4[1,1],xlabel = "Per capita GNI HICs (\$/10³)", ylabel = "Per capita GNI LMICs (\$/10³)",title = "(a) \n \n Just operating space")
b=Axis(f4[1,2], ylabel = "Total world GNI (\$/10¹²)", xlabel = "Atm CO2 (ppm)", title = "(b) \n \n Safe operating space");

#c=Axis(f4[1,3], ylabel = "Per Capita GNI (\$/10¹²)", xlabel = "Time (Years)");

l=lines!(a,PCO1_vary[1,:],PCO2_vary[1,:],color = :green);
m=lines!(a,PCO1_vary[2,:],PCO2_vary[2,:],color = :dodgerblue2);
h=lines!(a,PCO1_vary[3,:],PCO2_vary[3,:],color=:tan1);
ll=lines!(b,100*G_vary[1,:],OT_vary[1,:],color = :green)
mm=lines!(b,100*G_vary[2,:],OT_vary[2,:],color = :dodgerblue2)
he=lines!(b,100*G_vary[3,:],OT_vary[3,:],color=:tan1)

lines!(a,PCO1_vary_m1[1,:],PCO2_vary_m1[1,:],linestyle=:dash,color = :green);
lines!(a,PCO1_vary_m1[2,:],PCO2_vary_m1[2,:],linestyle=:dash,color = :dodgerblue2);
lines!(a,PCO1_vary_m1[3,:],PCO2_vary_m1[3,:],linestyle=:dash);
lines!(b,100*G_vary_m1[1,:],OT_vary_m1[1,:],linestyle=:dash,color = :green)
lines!(b,100*G_vary_m1[2,:],OT_vary_m1[2,:],linestyle=:dash,color = :dodgerblue2)
lines!(b,100*G_vary_m1[3,:],OT_vary_m1[3,:],linestyle=:dash,color=:tan1)

lines!(a,PCO1_vary_m2[1,:],PCO2_vary_m2[1,:],linestyle=:dot,color = :green);
lines!(a,PCO1_vary_m2[2,:],PCO2_vary_m2[2,:],linestyle=:dot,color = :dodgerblue2);
lines!(a,PCO1_vary_m2[3,:],PCO2_vary_m2[3,:],linestyle=:dot,color=:tan1);
lines!(b,100*G_vary_m2[1,:],OT_vary_m2[1,:],linestyle=:dot,color = :green)
lines!(b,100*G_vary_m2[2,:],OT_vary_m2[2,:],linestyle=:dot,color = :dodgerblue2)
lines!(b,100*G_vary_m2[3,:],OT_vary_m2[3,:],linestyle=:dot,color=:tan1)


#set the legend
Legend(f4[2,1:2],[l,m,h],["Low Intensity","Moderate Intensity","High Intensity"])


f4
# Out:
# ┌ Warning: Found `resolution` in the theme when creating a `Scene`. The `resolution` keyword for `Scene`s and `Figure`s has been deprecated. Use `Figure(; size = ...` or `Scene(; size = ...)` instead, which better reflects that this is a unitless size and not a pixel resolution. The key could also come from `set_theme!` calls or related theming functions.
# └ @ Makie C:\Users\admin\.julia\packages\Makie\rEu75\src\scenes.jl:227

# %%
save("SJOS_const_mig.svg",f4)
# Out:
# CairoMakie.Screen{SVG}

# %%
f5= Figure(resolution = (950, 900))
a=Axis(f5[1,1],xlabel = "Time", ylabel = "Difference atm CO2 (ppm)",title = "Migration influence on carbon concentration")
b=Axis(f5[1,2],xlabel = "Time", ylabel = "Difference YPC1/YPC2",title = "Migration influence on per capita GNI ratio")
#c=Axis(f4[1,3], ylabel = "Per Capita GNI (\$/10¹²)", xlabel = "Time (Years)");

l=lines!(a,100*G_vary[1,:]-100*G_vary_m1[1,:],color = :green);
m=lines!(a,100*G_vary[2,:]-100*G_vary_m1[2,:],color = :dodgerblue2);
h=lines!(a,100*G_vary[3,:]-100*G_vary_m1[3,:],color=:tan1);

lines!(a,(100*G_vary[1,:]-100*G_vary_m2[1,:]),color = :green,linestyle=:dot);
lines!(a,100*G_vary[2,:]-100*G_vary_m2[2,:],color = :dodgerblue2,linestyle=:dot);
lines!(a,100*G_vary[3,:]-100*G_vary_m2[3,:],color=:tan1,linestyle=:dot);

lines!(b,(PCO1_vary[1,:]./PCO2_vary[1,:])-(PCO1_vary_m1[1,:]./PCO2_vary_m1[1,:]),color = :green);
lines!(b,(PCO1_vary[2,:]./PCO2_vary[2,:])-(PCO1_vary_m1[2,:]./PCO2_vary_m1[2,:]),color = :dodgerblue2);
lines!(b,(PCO1_vary[3,:]./PCO2_vary[3,:])-(PCO1_vary_m1[3,:]./PCO2_vary_m1[3,:]),color=:tan1);

lines!(b,(PCO1_vary[1,:]./PCO2_vary[1,:])-(PCO1_vary_m2[1,:]./PCO2_vary_m2[1,:]),color = :green,linestyle=:dot);
lines!(b,(PCO1_vary[2,:]./PCO2_vary[2,:])-(PCO1_vary_m2[2,:]./PCO2_vary_m2[2,:]),color = :dodgerblue2,linestyle=:dot);
lines!(b,(PCO1_vary[3,:]./PCO2_vary[3,:])-(PCO1_vary_m2[3,:]./PCO2_vary_m2[3,:]),color=:tan1,linestyle=:dot);


#set the legend
Legend(f5[2,1:2],[l,m,h],["Low carbon intensities","Medium carbon intensities","High carbon intensities"])


f5
# Out:
# ┌ Warning: Found `resolution` in the theme when creating a `Scene`. The `resolution` keyword for `Scene`s and `Figure`s has been deprecated. Use `Figure(; size = ...` or `Scene(; size = ...)` instead, which better reflects that this is a unitless size and not a pixel resolution. The key could also come from `set_theme!` calls or related theming functions.
# └ @ Makie C:\Users\admin\.julia\packages\Makie\rEu75\src\scenes.jl:227

# %%
f5= Figure()
a=Axis(f5[1,1],xlabel = "Time", ylabel = "Per capita GNI ratio (YPC1/YPC2)",title = "Per capita GNI ratio for migration and emission scenarios")
#b=Axis(f5[1,2], ylabel = "Total World GNI (\$/10¹²)", xlabel = "Atm CO2 (ppm)", title = "Safe Operating Space");
#c=Axis(f4[1,3], ylabel = "Per Capita GNI (\$/10¹²)", xlabel = "Time (Years)");

l=lines!(a,(PCO1_vary[1,:]./PCO2_vary[1,:]),color = :green);
#m=lines!(a,(PCO1_vary[2,:]./PCO2_vary[2,:]),color = :dodgerblue2);
#h=lines!(a,(PCO1_vary[3,:]./PCO2_vary[3,:]),color=:tan1);

lines!(a,(PCO1_vary_m1[1,:]./PCO2_vary_m1[1,:]),color = :green,linestyle=:dash);
#lines!(a,(PCO1_vary_m1[2,:]./PCO2_vary_m1[2,:]),color = :dodgerblue2,linestyle=:dash);
#lines!(a,(PCO1_vary_m1[3,:]./PCO2_vary_m1[3,:]),color=:tan1,linestyle=:dash);

lines!(a,(PCO1_vary_m2[1,:]./PCO2_vary_m2[1,:]),color = :green,linestyle=:dot);
#lines!(a,(PCO1_vary_m2[2,:]./PCO2_vary_m2[2,:]),color = :dodgerblue2,linestyle=:dot);
#lines!(a,(PCO1_vary_m2[3,:]./PCO2_vary_m2[3,:]),color=:tan1,linestyle=:dot);


#set the legend
Legend(f5[1,2],[l,m,h],["Low carbon intensities","Medium carbon intensities","High carbon intensities"])


f5

# %%
f5= Figure()
a=Axis(f5[1,1],xlabel = "Time", ylabel = "Per capita GNI difference after scenario (10³\$)",title = "Difference per capita GNI ratio")
#b=Axis(f5[1,2], ylabel = "Total World GNI (\$/10¹²)", xlabel = "Atm CO2 (ppm)", title = "Safe Operating Space");
#c=Axis(f4[1,3], ylabel = "Per Capita GNI (\$/10¹²)", xlabel = "Time (Years)");

l=lines!(a,(PCO2_vary[1,:]./PCO1_vary[1,:])-(PCO2_vary_m1[1,:]./PCO1_vary_m2[1,:]),color = :green);
m=lines!(a,(PCO2_vary[2,:]./PCO1_vary[2,:])-(PCO2_vary_m1[2,:]./PCO1_vary_m2[2,:]),color = :dodgerblue2);
h=lines!(a,(PCO2_vary[3,:]./PCO1_vary[3,:])-(PCO2_vary_m1[3,:]./PCO1_vary_m2[3,:]),color=:tan1);

lines!(a,(PCO2_vary[1,:]./PCO1_vary[1,:])-(PCO2_vary_m1[1,:]./PCO1_vary_m2[1,:]),color = :green,linestyle=:dot);
lines!(a,(PCO2_vary[2,:]./PCO1_vary[2,:])-(PCO2_vary_m1[2,:]./PCO1_vary_m2[2,:]),color = :dodgerblue2,linestyle=:dot);
lines!(a,(PCO2_vary[3,:]./PCO1_vary[3,:])-(PCO2_vary_m1[3,:]./PCO1_vary_m2[3,:]),color=:tan1,linestyle=:dot);


#set the legend
Legend(f5[1,2],[l,m,h],["Low carbon intensities","Medium carbon intensities","High carbon intensities"])


f5

# %%
f5= Figure()
a=Axis(f5[1,1],xlabel = "World Population", ylabel = "Population in Regions",title = "Population Distribution")
#b=Axis(f5[1,2], ylabel = "Total World GNI (\$/10¹²)", xlabel = "Atm CO2 (ppm)", title = "Safe Operating Space");
#c=Axis(f4[1,3], ylabel = "Per Capita GNI (\$/10¹²)", xlabel = "Time (Years)");

l=lines!(a,P_vary[1,:],P1_vary[1,:],color = :black);
lines!(a,P_vary[2,:],P1_vary[2,:],color = :black);
lines!(a,P_vary[3,:],P1_vary[3,:],color=:black);

d=lines!(a,P_vary[1,:],P2_vary[1,:],color = :orangered);
lines!(a,P_vary[2,:],P2_vary[2,:],color = :orangered);
lines!(a,P_vary[3,:],P2_vary[3,:],color=:orangered);
# ll=lines!(b,100*G_vary[1,:],OT_vary[1,:],color = :green)
# mm=lines!(b,100*G_vary[2,:],OT_vary[2,:],color = :dodgerblue2)
# he=lines!(b,100*G_vary[3,:],OT_vary[3,:],color=:tan1)

m=lines!(a,P_vary_m1[1,:],P1_vary_m1[1,:],linestyle=:dash,color = :black);
lines!(a,P_vary_m1[2,:],P1_vary_m1[2,:],linestyle=:dash,color = :black);
lines!(a,P_vary_m1[3,:],P1_vary_m1[3,:],linestyle=:dash,color=:black);

lines!(a,P_vary_m1[1,:],P2_vary_m1[1,:],linestyle=:dash,color = :orangered);
lines!(a,P_vary_m1[2,:],P2_vary_m1[2,:],linestyle=:dash,color = :orangered);
lines!(a,P_vary_m1[3,:],P2_vary_m1[3,:],linestyle=:dash,color=:orangered);
# lines!(b,100*G_vary_m1[1,:],OT_vary_m1[1,:],linestyle=:dash,color = :green)
# lines!(b,100*G_vary_m1[2,:],OT_vary_m1[2,:],linestyle=:dash,color = :dodgerblue2)
# lines!(b,100*G_vary_m1[3,:],OT_vary_m1[3,:],linestyle=:dash,color=:tan1)

lines!(a,P_vary_m2[1,:],P1_vary_m2[1,:],linestyle=:dot,color = :black);
lines!(a,P_vary_m2[2,:],P1_vary_m2[2,:],linestyle=:dot,color = :black);
lines!(a,P_vary_m2[3,:],P1_vary_m2[3,:],linestyle=:dot,color=:black);

lines!(a,P_vary_m2[1,:],P2_vary_m2[1,:],linestyle=:dot,color = :orangered);
lines!(a,P_vary_m2[2,:],P2_vary_m2[2,:],linestyle=:dot,color = :orangered);
lines!(a,P_vary_m2[3,:],P2_vary_m2[3,:],linestyle=:dot,color=:orangered);
# lines!(b,100*G_vary_m2[1,:],OT_vary_m2[1,:],linestyle=:dot,color = :green)
# lines!(b,100*G_vary_m2[2,:],OT_vary_m2[2,:],linestyle=:dot,color = :dodgerblue2)
# lines!(b,100*G_vary_m2[3,:],OT_vary_m2[3,:],linestyle=:dot,color=:tan1)


#set the legend
Legend(f5[1,2],[l,d],["HICs","LICs"])


f5

# %%
f5= Figure()
a=Axis(f5[1,1],xlabel = "Time", ylabel = "Population share of total",title = "Regional Population vs total world ")
#b=Axis(f5[1,2], ylabel = "Total World GNI (\$/10¹²)", xlabel = "Atm CO2 (ppm)", title = "Safe Operating Space");
#c=Axis(f4[1,3], ylabel = "Per Capita GNI (\$/10¹²)", xlabel = "Time (Years)");

l=lines!(a,P1_vary[1,:]./P_vary[1,:],color = :black);
lines!(a,P1_vary[2,:]./P_vary[2,:],color = :black);
lines!(a,P1_vary[3,:]./P_vary[3,:],color=:black);

d=lines!(a,P2_vary[1,:]./P_vary[1,:],color = :orangered);
lines!(a,P2_vary[2,:]./P_vary[2,:],color = :orangered);
lines!(a,P2_vary[3,:]./P_vary[3,:],color=:orangered);
# ll=lines!(b,100*G_vary[1,:],OT_vary[1,:],color = :green)
# mm=lines!(b,100*G_vary[2,:],OT_vary[2,:],color = :dodgerblue2)
# he=lines!(b,100*G_vary[3,:],OT_vary[3,:],color=:tan1)

m=lines!(a,P1_vary_m1[1,:]./P_vary_m1[1,:],linestyle=:dash,color = :black);
lines!(a,P1_vary_m1[2,:]./P_vary_m1[2,:],linestyle=:dash,color = :black);
lines!(a,P1_vary_m1[3,:]./P_vary_m1[3,:],linestyle=:dash,color=:black);

lines!(a,P2_vary_m1[1,:]./P_vary_m1[1,:],linestyle=:dash,color = :orangered);
lines!(a,P2_vary_m1[2,:]./P_vary_m1[2,:],linestyle=:dash,color = :orangered);
lines!(a,P2_vary_m1[3,:]./P_vary_m1[3,:],linestyle=:dash,color=:orangered);
# lines!(b,100*G_vary_m1[1,:],OT_vary_m1[1,:],linestyle=:dash,color = :green)
# lines!(b,100*G_vary_m1[2,:],OT_vary_m1[2,:],linestyle=:dash,color = :dodgerblue2)
# lines!(b,100*G_vary_m1[3,:],OT_vary_m1[3,:],linestyle=:dash,color=:tan1)

lines!(a,P1_vary_m2[1,:]./P_vary_m2[1,:],linestyle=:dot,color = :black);
lines!(a,P1_vary_m2[2,:]./P_vary_m2[2,:],linestyle=:dot,color = :black);
lines!(a,P1_vary_m2[3,:]./P_vary_m2[3,:],linestyle=:dot,color=:black);

lines!(a,P2_vary_m2[1,:]./P_vary_m2[1,:],linestyle=:dot,color = :orangered);
lines!(a,P2_vary_m2[2,:]./P_vary_m2[2,:],linestyle=:dot,color = :orangered);
lines!(a,P2_vary_m2[3,:]./P_vary_m2[3,:],linestyle=:dot,color=:orangered);
# lines!(b,100*G_vary_m2[1,:],OT_vary_m2[1,:],linestyle=:dot,color = :green)
# lines!(b,100*G_vary_m2[2,:],OT_vary_m2[2,:],linestyle=:dot,color = :dodgerblue2)
# lines!(b,100*G_vary_m2[3,:],OT_vary_m2[3,:],linestyle=:dot,color=:tan1)


#set the legend
Legend(f5[1,2],[l,d],["HICs","LICs"])


f5

# %%
f5= Figure()
a=Axis(f5[1,1],xlabel = "Time", ylabel = "Population1/population2",title = "Regional distribution population")
#b=Axis(f5[1,2], ylabel = "Total World GNI (\$/10¹²)", xlabel = "Atm CO2 (ppm)", title = "Safe Operating Space");
#c=Axis(f4[1,3], ylabel = "Per Capita GNI (\$/10¹²)", xlabel = "Time (Years)");

# l=lines!(a,P_vary[1,:]./P1_vary[1,:],color = :black);
# lines!(a,P_vary[2,:]./P1_vary[2,:],color = :black);
# lines!(a,P_vary[3,:]./P1_vary[3,:],color=:black);

d=lines!(a,P1_vary[1,:]./P2_vary[1,:],color = :orangered);
lines!(a,P1_vary[2,:]./P2_vary[2,:],color = :orangered);
lines!(a,P1_vary[3,:]./P2_vary[3,:],color=:orangered);
# ll=lines!(b,100*G_vary[1,:],OT_vary[1,:],color = :green)
# mm=lines!(b,100*G_vary[2,:],OT_vary[2,:],color = :dodgerblue2)
# he=lines!(b,100*G_vary[3,:],OT_vary[3,:],color=:tan1)

# m=lines!(a,P_vary_m1[1,:]./P1_vary_m1[1,:],linestyle=:dash,color = :black);
# lines!(a,P_vary_m1[2,:]./P1_vary_m1[2,:],linestyle=:dash,color = :black);
# lines!(a,P_vary_m1[3,:]./P1_vary_m1[3,:],linestyle=:dash,color=:black);

lines!(a,P1_vary_m1[1,:]./P2_vary_m1[1,:],linestyle=:dash,color = :orangered);
lines!(a,P1_vary_m1[2,:]./P2_vary_m1[2,:],linestyle=:dash,color = :orangered);
lines!(a,P1_vary_m1[3,:]./P2_vary_m1[3,:],linestyle=:dash,color=:orangered);
# lines!(b,100*G_vary_m1[1,:],OT_vary_m1[1,:],linestyle=:dash,color = :green)
# lines!(b,100*G_vary_m1[2,:],OT_vary_m1[2,:],linestyle=:dash,color = :dodgerblue2)
# lines!(b,100*G_vary_m1[3,:],OT_vary_m1[3,:],linestyle=:dash,color=:tan1)

# lines!(a,P_vary_m2[1,:]./P1_vary_m2[1,:],linestyle=:dot,color = :black);
# lines!(a,P_vary_m2[2,:]./P1_vary_m2[2,:],linestyle=:dot,color = :black);
# lines!(a,P_vary_m2[3,:]./P1_vary_m2[3,:],linestyle=:dot,color=:black);

lines!(a,P1_vary_m2[1,:]./P2_vary_m2[1,:],linestyle=:dot,color = :orangered);
lines!(a,P1_vary_m2[2,:]./P2_vary_m2[2,:],linestyle=:dot,color = :orangered);
lines!(a,P1_vary_m2[3,:]./P2_vary_m2[3,:],linestyle=:dot,color=:orangered);
# lines!(b,100*G_vary_m2[1,:],OT_vary_m2[1,:],linestyle=:dot,color = :green)
# lines!(b,100*G_vary_m2[2,:],OT_vary_m2[2,:],linestyle=:dot,color = :dodgerblue2)
# lines!(b,100*G_vary_m2[3,:],OT_vary_m2[3,:],linestyle=:dot,color=:tan1)


#set the legend
#Legend(f5[1,2],[l,d],["HICs","LICs"])


f5

# %%
f5= Figure()
a=Axis(f5[1,1],xlabel = "G", ylabel = "P total",title = "P vs G")
#b=Axis(f5[1,2], ylabel = "Total World GNI (\$/10¹²)", xlabel = "Atm CO2 (ppm)", title = "Safe Operating Space");
#c=Axis(f4[1,3], ylabel = "Per Capita GNI (\$/10¹²)", xlabel = "Time (Years)");

l=lines!(a,G_vary[1,:],P_vary[1,:],color = :black);
lines!(a,G_vary[2,:],P_vary[2,:],color = :black);
lines!(a,G_vary[3,:],P_vary[3,:],color=:black);

# d=lines!(a,P_vary[1,:]./G_vary[1,:],color = :orangered);
# lines!(a,P_vary[2,:]./G_vary[2,:],color = :orangered);
# lines!(a,P_vary[3,:]./G_vary[3,:],color=:orangered);
# ll=lines!(b,100*G_vary[1,:],OT_vary[1,:],color = :green)
# mm=lines!(b,100*G_vary[2,:],OT_vary[2,:],color = :dodgerblue2)
# he=lines!(b,100*G_vary[3,:],OT_vary[3,:],color=:tan1)

m=lines!(a,G_vary_m1[1,:],P_vary_m1[1,:],linestyle=:dash,color = :black);
lines!(a,G_vary_m1[2,:],P_vary_m1[2,:],linestyle=:dash,color = :black);
lines!(a,G_vary_m1[3,:],P_vary_m1[3,:],linestyle=:dash,color=:black);

# lines!(a,P_vary_m1[1,:]./G_vary_m1[1,:],linestyle=:dash,color = :orangered);
# lines!(a,P_vary_m1[2,:]./G_vary_m1[2,:],linestyle=:dash,color = :orangered);
# lines!(a,P_vary_m1[3,:]./G_vary_m1[3,:],linestyle=:dash,color=:orangered);
# lines!(b,100*G_vary_m1[1,:],OT_vary_m1[1,:],linestyle=:dash,color = :green)
# lines!(b,100*G_vary_m1[2,:],OT_vary_m1[2,:],linestyle=:dash,color = :dodgerblue2)
# lines!(b,100*G_vary_m1[3,:],OT_vary_m1[3,:],linestyle=:dash,color=:tan1)

lines!(a,G_vary_m2[1,:],P_vary_m2[1,:],linestyle=:dot,color = :black);
lines!(a,G_vary_m2[2,:],P_vary_m2[2,:],linestyle=:dot,color = :black);
lines!(a,G_vary_m2[3,:],P_vary_m2[3,:],linestyle=:dot,color=:black);

# lines!(a,P_vary_m2[1,:]./G_vary_m2[1,:],linestyle=:dot,color = :orangered);
# lines!(a,P_vary_m2[2,:]./G_vary_m2[2,:],linestyle=:dot,color = :orangered);
# lines!(a,P_vary_m2[3,:]./G_vary_m2[3,:],linestyle=:dot,color=:orangered);
# lines!(b,100*G_vary_m2[1,:],OT_vary_m2[1,:],linestyle=:dot,color = :green)
# lines!(b,100*G_vary_m2[2,:],OT_vary_m2[2,:],linestyle=:dot,color = :dodgerblue2)
# lines!(b,100*G_vary_m2[3,:],OT_vary_m2[3,:],linestyle=:dot,color=:tan1)


#set the legend
Legend(f5[1,2],[l,d],["HICs","LICs"])


f5
# Out:
# type Axis has no field plots
#
#
#
# Stacktrace:
#
#   [1] getproperty
#
#     @ .\Base.jl:37 [inlined]
#
#   [2] legendelements(plot::Axis, legend::Legend)
#
#     @ Makie C:\Users\admin\.julia\packages\Makie\1hq9u\src\makielayout\blocks\legend.jl:435
#
#   [3] LegendEntry(label::String, contentelement::Axis, legend::Legend; kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#
#     @ Makie C:\Users\admin\.julia\packages\Makie\1hq9u\src\makielayout\blocks\legend.jl:337
#
#   [4] LegendEntry(label::String, contentelement::Axis, legend::Legend)
#
#     @ Makie C:\Users\admin\.julia\packages\Makie\1hq9u\src\makielayout\blocks\legend.jl:331
#
#   [5] (::Makie.var"#1969#1970"{Legend})(::Tuple{Axis, String})
#
#     @ Makie .\none:0
#
#   [6] iterate
#
#     @ .\generator.jl:47 [inlined]
#
# ...

# %%
f5= Figure()
a=Axis(f5[1,1],xlabel = "G", ylabel = "P total",title = "P vs G")
#b=Axis(f5[1,2], ylabel = "Total World GNI (\$/10¹²)", xlabel = "Atm CO2 (ppm)", title = "Safe Operating Space");
#c=Axis(f4[1,3], ylabel = "Per Capita GNI (\$/10¹²)", xlabel = "Time (Years)");

##world pop
l=lines!(a,G_vary[1,:],P_vary[1,:],color = :black);
lines!(a,G_vary[2,:],P_vary[2,:],color = :black);
lines!(a,G_vary[3,:],P_vary[3,:],color=:black);

m=lines!(a,G_vary_m1[1,:],P_vary_m1[1,:],linestyle=:dash,color = :black);
lines!(a,G_vary_m1[2,:],P_vary_m1[2,:],linestyle=:dash,color = :black);
lines!(a,G_vary_m1[3,:],P_vary_m1[3,:],linestyle=:dash,color=:black);

lines!(a,G_vary_m2[1,:],P_vary_m2[1,:],linestyle=:dot,color = :black);
lines!(a,G_vary_m2[2,:],P_vary_m2[2,:],linestyle=:dot,color = :black);
lines!(a,G_vary_m2[3,:],P_vary_m2[3,:],linestyle=:dot,color=:black);


### pop 1 
lines!(a,G_vary[1,:],P1_vary[1,:],color = :black);
lines!(a,G_vary[2,:],P1_vary[2,:],color = :black);
lines!(a,G_vary[3,:],P1_vary[3,:],color=:black);

lines!(a,G_vary_m1[1,:],P1_vary_m1[1,:],linestyle=:dash,color = :black);
lines!(a,G_vary_m1[2,:],P1_vary_m1[2,:],linestyle=:dash,color = :black);
lines!(a,G_vary_m1[3,:],P1_vary_m1[3,:],linestyle=:dash,color=:black);

lines!(a,G_vary_m2[1,:],P1_vary_m2[1,:],linestyle=:dot,color = :black);
lines!(a,G_vary_m2[2,:],P1_vary_m2[2,:],linestyle=:dot,color = :black);
lines!(a,G_vary_m2[3,:],P1_vary_m2[3,:],linestyle=:dot,color=:black);


##pop2 
lines!(a,G_vary[1,:],P2_vary[1,:],color = :black);
lines!(a,G_vary[2,:],P2_vary[2,:],color = :black);
lines!(a,G_vary[3,:],P2_vary[3,:],color=:black);

lines!(a,G_vary_m1[1,:],P2_vary_m1[1,:],linestyle=:dash,color = :black);
lines!(a,G_vary_m1[2,:],P2_vary_m1[2,:],linestyle=:dash,color = :black);
lines!(a,G_vary_m1[3,:],P2_vary_m1[3,:],linestyle=:dash,color=:black);

lines!(a,G_vary_m2[1,:],P2_vary_m2[1,:],linestyle=:dot,color = :black);
lines!(a,G_vary_m2[2,:],P2_vary_m2[2,:],linestyle=:dot,color = :black);
lines!(a,G_vary_m2[3,:],P2_vary_m2[3,:],linestyle=:dot,color=:black);



Legend(f5[1,2],[l,d],["HICs","LICs"])


f5
# Out:
# type Axis has no field plots
#
#
#
# Stacktrace:
#
#   [1] getproperty
#
#     @ .\Base.jl:37 [inlined]
#
#   [2] legendelements(plot::Axis, legend::Legend)
#
#     @ Makie C:\Users\admin\.julia\packages\Makie\1hq9u\src\makielayout\blocks\legend.jl:435
#
#   [3] LegendEntry(label::String, contentelement::Axis, legend::Legend; kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#
#     @ Makie C:\Users\admin\.julia\packages\Makie\1hq9u\src\makielayout\blocks\legend.jl:337
#
#   [4] LegendEntry(label::String, contentelement::Axis, legend::Legend)
#
#     @ Makie C:\Users\admin\.julia\packages\Makie\1hq9u\src\makielayout\blocks\legend.jl:331
#
#   [5] (::Makie.var"#1969#1970"{Legend})(::Tuple{Axis, String})
#
#     @ Makie .\none:0
#
#   [6] iterate
#
#     @ .\generator.jl:47 [inlined]
#
# ...

# %%
f5= Figure()
a=Axis(f5[1,1],xlabel = "Time", ylabel = "P total/G",title = "per capita concentration")
#b=Axis(f5[1,2], ylabel = "Total World GNI (\$/10¹²)", xlabel = "Atm CO2 (ppm)", title = "Safe Operating Space");
#c=Axis(f4[1,3], ylabel = "Per Capita GNI (\$/10¹²)", xlabel = "Time (Years)");

l=lines!(a,100*G_vary[1,:]./P_vary[1,:],color = :black);
lines!(a,100*G_vary[2,:]./P_vary[2,:],color = :black);
lines!(a,100*G_vary[3,:]./P_vary[3,:],color=:black);

# d=lines!(a,P_vary[1,:]./G_vary[1,:],color = :orangered);
# lines!(a,P_vary[2,:]./G_vary[2,:],color = :orangered);
# lines!(a,P_vary[3,:]./G_vary[3,:],color=:orangered);
# ll=lines!(b,100*G_vary[1,:],OT_vary[1,:],color = :green)
# mm=lines!(b,100*G_vary[2,:],OT_vary[2,:],color = :dodgerblue2)
# he=lines!(b,100*G_vary[3,:],OT_vary[3,:],color=:tan1)

m=lines!(a,100*G_vary_m1[1,:]./P_vary_m1[1,:],linestyle=:dash,color = :black);
lines!(a,100*G_vary_m1[2,:]./P_vary_m1[2,:],linestyle=:dash,color = :black);
lines!(a,100*G_vary_m1[3,:]./P_vary_m1[3,:],linestyle=:dash,color=:black);

# lines!(a,P_vary_m1[1,:]./G_vary_m1[1,:],linestyle=:dash,color = :orangered);
# lines!(a,P_vary_m1[2,:]./G_vary_m1[2,:],linestyle=:dash,color = :orangered);
# lines!(a,P_vary_m1[3,:]./G_vary_m1[3,:],linestyle=:dash,color=:orangered);
# lines!(b,100*G_vary_m1[1,:],OT_vary_m1[1,:],linestyle=:dash,color = :green)
# lines!(b,100*G_vary_m1[2,:],OT_vary_m1[2,:],linestyle=:dash,color = :dodgerblue2)
# lines!(b,100*G_vary_m1[3,:],OT_vary_m1[3,:],linestyle=:dash,color=:tan1)

lines!(a,100*G_vary_m2[1,:]./P_vary_m2[1,:],linestyle=:dot,color = :black);
lines!(a,100*G_vary_m2[2,:]./P_vary_m2[2,:],linestyle=:dot,color = :black);
lines!(a,100*G_vary_m2[3,:]./P_vary_m2[3,:],linestyle=:dot,color=:black);

# lines!(a,P_vary_m2[1,:]./G_vary_m2[1,:],linestyle=:dot,color = :orangered);
# lines!(a,P_vary_m2[2,:]./G_vary_m2[2,:],linestyle=:dot,color = :orangered);
# lines!(a,P_vary_m2[3,:]./G_vary_m2[3,:],linestyle=:dot,color=:orangered);
# lines!(b,100*G_vary_m2[1,:],OT_vary_m2[1,:],linestyle=:dot,color = :green)
# lines!(b,100*G_vary_m2[2,:],OT_vary_m2[2,:],linestyle=:dot,color = :dodgerblue2)
# lines!(b,100*G_vary_m2[3,:],OT_vary_m2[3,:],linestyle=:dot,color=:tan1)


#set the legend
Legend(f5[1,2],[l,d],["HICs","LICs"])


f5

# %%
f5= Figure()
a=Axis(f5[1,1],xlabel = "Population 1 / Population 2", ylabel = "Carbon Concentration (ppm)",title = "Population distribution and carbon concentration")
#b=Axis(f5[1,2], ylabel = "Total World GNI (\$/10¹²)", xlabel = "Atm CO2 (ppm)", title = "Safe Operating Space");
#c=Axis(f4[1,3], ylabel = "Per Capita GNI (\$/10¹²)", xlabel = "Time (Years)");

l=lines!(a,P1_vary[1,:]./P2_vary[1,:],100*G_vary[1,:],color = :green);
m=lines!(a,P1_vary[2,:]./P2_vary[2,:],100*G_vary[2,:],color = :dodgerblue2);
h=lines!(a,P1_vary[3,:]./P2_vary[3,:],100*G_vary[3,:],color=:tan1);

lines!(a,P1_vary_m1[1,:]./P2_vary_m1[1,:],100*G_vary_m1[1,:],color = :green,linestyle=:dash);
lines!(a,P1_vary_m1[2,:]./P2_vary_m1[2,:],100*G_vary_m1[2,:],color = :dodgerblue2,linestyle=:dash);
lines!(a,P1_vary_m1[3,:]./P2_vary_m1[3,:],100*G_vary_m1[3,:],color=:tan1,linestyle=:dash);

lines!(a,P1_vary_m2[1,:]./P2_vary_m2[1,:],100*G_vary_m2[1,:],color = :green,linestyle=:dot);
lines!(a,P1_vary_m2[2,:]./P2_vary_m2[2,:],100*G_vary_m2[2,:],color = :dodgerblue2,linestyle=:dot);
lines!(a,P1_vary_m2[3,:]./P2_vary_m2[3,:],100*G_vary_m2[3,:],color=:tan1,linestyle=:dot);


#set the legend
Legend(f5[1,2],[l,m,h],["Low carbon intensities","Medium carbon intensities","High carbon intensities"])


f5

# %%
f5= Figure()
a=Axis(f5[1,1],xlabel = "Population ratio (P1/P2) shift", ylabel = "Carbon Concentration shift (ppm)",title = "Population, carbon concentration shifts for migration scenarios")
#b=Axis(f5[1,2], ylabel = "Total World GNI (\$/10¹²)", xlabel = "Atm CO2 (ppm)", title = "Safe Operating Space");
#c=Axis(f4[1,3], ylabel = "Per Capita GNI (\$/10¹²)", xlabel = "Time (Years)");

l=lines!(a,(P1_vary[1,:]./P2_vary[1,:])-(P1_vary_m1[1,:]./P2_vary_m1[1,:]),(100*G_vary[1,:]-100*G_vary_m1[1,:]),color = :green);
m=lines!(a,(P1_vary[2,:]./P2_vary[2,:])-(P1_vary_m1[2,:]./P2_vary_m1[2,:]),(100*G_vary[2,:]-100*G_vary_m1[2,:]),color = :dodgerblue2);
h=lines!(a,(P1_vary[3,:]./P2_vary[3,:])-(P1_vary_m1[3,:]./P2_vary_m1[3,:]),(100*G_vary[3,:]-100*G_vary_m1[3,:]),color=:tan1);

lines!(a,(P1_vary[1,:]./P2_vary[1,:])-(P1_vary_m2[1,:]./P2_vary_m2[1,:]),(100*G_vary[1,:]-100*G_vary_m2[1,:]),color = :green,linestyle=:dot);
lines!(a,(P1_vary[2,:]./P2_vary[2,:])-(P1_vary_m2[2,:]./P2_vary_m2[2,:]),(100*G_vary[2,:]-100*G_vary_m2[2,:]),color = :dodgerblue2,linestyle=:dot);
lines!(a,(P1_vary[3,:]./P2_vary[3,:])-(P1_vary_m2[3,:]./P2_vary_m2[3,:]),(100*G_vary[3,:]-100*G_vary_m2[3,:]),color=:tan1,linestyle=:dot);




#set the legend
Legend(f5[1,2],[l,m,h],["Low carbon intensities","Medium carbon intensities","High carbon intensities"])


f5

# %%
f5= Figure()
a=Axis(f5[1,1],xlabel = "Migrants from 2 to 1", ylabel = "Carbon Concentration shift (ppm)",title = "Population, carbon concentration shifts for migration scenarios")
#b=Axis(f5[1,2], ylabel = "Total World GNI (\$/10¹²)", xlabel = "Atm CO2 (ppm)", title = "Safe Operating Space");
#c=Axis(f4[1,3], ylabel = "Per Capita GNI (\$/10¹²)", xlabel = "Time (Years)");

l=lines!(a,(P_vary_m1[1,:]-P2_vary_m1[1,:]),(100*G_vary[1,:]-100*G_vary_m1[1,:]),color = :green);
m=lines!(a,(P_vary[2,:]-P2_vary[2,:]),(100*G_vary[2,:]-100*G_vary_m1[2,:]),color = :dodgerblue2);
h=lines!(a,(P_vary[3,:]-P2_vary[3,:]),(100*G_vary[3,:]-100*G_vary_m1[3,:]),color=:tan1);

lines!(a,(P1_vary[1,:]./P2_vary[1,:])-(P1_vary_m2[1,:]./P2_vary_m2[1,:]),(100*G_vary[1,:]-100*G_vary_m2[1,:]),color = :green,linestyle=:dot);
lines!(a,(P1_vary[2,:]./P2_vary[2,:])-(P1_vary_m2[2,:]./P2_vary_m2[2,:]),(100*G_vary[2,:]-100*G_vary_m2[2,:]),color = :dodgerblue2,linestyle=:dot);
lines!(a,(P1_vary[3,:]./P2_vary[3,:])-(P1_vary_m2[3,:]./P2_vary_m2[3,:]),(100*G_vary[3,:]-100*G_vary_m2[3,:]),color=:tan1,linestyle=:dot);


#set the legend
Legend(f5[1,2],[l,m,h],["Low carbon intensities","Medium carbon intensities","High carbon intensities"])


f5

# %%
f5= Figure()
a=Axis(f5[1,1],xlabel = "Population 1 / Population 2", ylabel = "Capital 1 / Capital 2",title = "Population distribution and carbon concentration")
#b=Axis(f5[1,2], ylabel = "Total World GNI (\$/10¹²)", xlabel = "Atm CO2 (ppm)", title = "Safe Operating Space");
#c=Axis(f4[1,3], ylabel = "Per Capita GNI (\$/10¹²)", xlabel = "Time (Years)");

#l=lines!(a,P1_vary[1,:]./P2_vary[1,:],K1_vary[1,:]./K2_vary[1,:],color = :green);
 m=lines!(a,P1_vary[2,:]./P2_vary[2,:],K1_vary[2,:]./K2_vary[2,:],color = :dodgerblue2);
# h=lines!(a,P1_vary[3,:]./P2_vary[3,:],K1_vary[2,:]./K2_vary[2,:],color=:tan1);

#lines!(a,P1_vary_m1[1,:]./P2_vary_m1[1,:],K1_vary_m1[1,:]./K2_vary_m1[1,:],color = :green,linestyle=:dash);
 lines!(a,P1_vary_m1[2,:]./P2_vary_m1[2,:],K1_vary_m1[2,:]./K2_vary_m1[2,:],color = :dodgerblue2,linestyle=:dash);
# lines!(a,P1_vary_m1[3,:]./P2_vary_m1[3,:],K1_vary_m1[3,:]./K2_vary_m1[3,:],color=:tan1,linestyle=:dash);

#lines!(a,P1_vary_m2[1,:]./P2_vary_m2[1,:],K1_vary_m2[1,:]./K2_vary_m2[1,:],color = :green,linestyle=:dot);
 lines!(a,P1_vary_m2[2,:]./P2_vary_m2[2,:],K1_vary_m2[2,:]./K2_vary_m2[2,:],color = :dodgerblue2,linestyle=:dot);
# lines!(a,P1_vary_m2[3,:]./P2_vary_m2[3,:],K1_vary_m2[3,:]./K2_vary_m2[3,:],color=:tan1,linestyle=:dot);


#set the legend
Legend(f5[1,2],[l,m,h],["Low carbon intensities","Medium carbon intensities","High carbon intensities"])


f5
